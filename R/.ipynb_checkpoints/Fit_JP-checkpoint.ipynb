# %%
library(zoo)
library(forecast)
library(tseries)
library(fUnitRoots)
library(FinTS)
library(timeDate)
library(timeSeries)
library(fBasics)
library(fGarch) 
library(rugarch)
library(TSA)
# Out:
# Attaching package: 'zoo'
#
# The following objects are masked from 'package:base':
#
#     as.Date, as.Date.numeric
#
# Loading required package: timeDate
# Loading required package: timeSeries
#
# Attaching package: 'timeSeries'
#
# The following object is masked from 'package:zoo':
#
#     time<-
#
# Loading required package: fBasics
#
# Attaching package: 'FinTS'
#
# The following object is masked from 'package:forecast':
#
#     Acf
#
# Loading required package: parallel
#
# Attaching package: 'rugarch'
#
# The following object is masked from 'package:stats':
#
#     sigma
#
#
# Attaching package: 'TSA'
#
# The following objects are masked from 'package:timeDate':
#
#     kurtosis, skewness
#
# The following objects are masked from 'package:stats':
#
#     acf, arima
#
# The following object is masked from 'package:utils':
#
#     tar

# %%
tsValuesLog = c(4.638034199607264,
 4.653428780327883,
 4.656379326834832,
 4.674638411143251,
 4.669038482575358,
 4.689026842074377,
 4.71808360651318,
 4.705978857704906,
 4.711681039753262,
 4.743796701401257,
 4.774524699557622,
 4.774595610646965,
 4.74906704605694,
 4.769501721722167,
 4.764545479435795,
 4.762767775533455,
 4.716089721623073,
 4.741665930576629,
 4.751579550432798,
 4.752937391872405,
 4.764005589626726,
 4.775832369013315,
 4.764909505948106,
 4.764922291355695,
 4.791210652390799,
 4.791688756319445,
 4.764393691536069,
 4.7785552644733205,
 4.793914406582772,
 4.809649437865055,
 4.799212782232742,
 4.759893558938191,
 4.745310317710208,
 4.752435214032227,
 4.710186742498752,
 4.72249978552452,
 4.680445547905724,
 4.673109168996284,
 4.612703737394917,
 4.631594956063711,
 4.647841669149346,
 4.672035996884754,
 4.671442827669122,
 4.694667138041749,
 4.668847086036799,
 4.604829127834371,
 4.574356276428781,
 4.513876927541701,
 4.501147663706664,
 4.531693706708459,
 4.583486791156933,
 4.594311442653216,
 4.571039297671946,
 4.570728833473735,
 4.5471914357642405,
 4.552793146666349,
 4.513874736358801,
 4.5038802631035075,
 4.491636359641103,
 4.499263965905131,
 4.511969878836264,
 4.501358470320116,
 4.507734849637381,
 4.537455425940052,
 4.521495055714999,
 4.508724261469839,
 4.4716445076329565,
 4.447026377557349,
 4.435058978537945,
 4.403402778245706,
 4.413016451360626,
 4.4228998278834615,
 4.414312298171851,
 4.4132442544912385,
 4.402405076549179,
 4.420972069556961,
 4.395999803646504,
 4.387336263612679,
 4.372512771055031,
 4.34335986806388,
 4.341148649002818,
 4.339158276946601,
 4.351045383731702,
 4.3540990138323,
 4.34333778005877,
 4.362716386139382,
 4.412384874561534,
 4.3975603592351336,
 4.377852936902168,
 4.373429787448363,
 4.368622195250196,
 4.365527519767038,
 4.358441939366436,
 4.36961492711687,
 4.3948256270077115,
 4.4283196359065915,
 4.489288965733804,
 4.532616697306339,
 4.551452903482104,
 4.582497082815149,
 4.614314251302477,
 4.5771307289568455,
 4.6018918180074575,
 4.583050336003947,
 4.597238815661811,
 4.5826177815175795,
 4.605906914536956,
 4.639185064575369,
 4.642094032592568,
 4.6262004907523515,
 4.62829571768981,
 4.629454910525391,
 4.62275270360472,
 4.625589289890181,
 4.622420539394619,
 4.634183208250874,
 4.676799445813904,
 4.682375641696988,
# 4 o x o x o o o o o o o  o  o  o
# 5 x x x x o o o o o o o  o  o  o
# 6 x x x x o o o o o o o  o  o  o
# 7 x o x o x x o o o o o  o  o  o

# %%
model = arima(tsValuesLog_d_1,order = c(2,0,2))

# %%
model
# Out:
# Call:
# arima(x = tsValuesLog_d_1, order = c(2, 0, 2))
#
# Coefficients:
#           ar1     ar2     ma1     ma2  intercept
#       -0.2664  0.0941  0.5009  0.1468     0.0003
# s.e.   0.3676  0.2768  0.3670  0.2771     0.0024
#
# sigma^2 estimated as 0.0004871:  log likelihood = 414.21,  aic = -818.42

# %%
Box.test(model$residuals,lag = 20,fitdf = 4)
# Out:
# 	Box-Pierce test
#
# data:  model$residuals
# X-squared = 18.375, df = 16, p-value = 0.3024

# %%
ArchTest(model$residuals)
# Out:
# 	ARCH LM-test; Null hypothesis: no ARCH effects
#
# data:  model$residuals
# Chi-squared = 16.082, df = 12, p-value = 0.1875

# %%
model = ARIMA(tsValuesLog_d_1,order=c(1,0,2))

# %%
model
# Out:
# Call:
# stats::arima(x = x, order = order, seasonal = seasonal, xreg = xreg, include.mean = include.mean,
#     transform.pars = transform.pars, fixed = fixed, init = init, method = method,
#     n.cond = n.cond, optim.control = optim.control, kappa = kappa)
#
# Coefficients:
#           ar1     ma1     ma2  intercept
#       -0.2991  0.5329  0.2349     0.0004
# s.e.   0.3964  0.3909  0.1020     0.0023
#
# sigma^2 estimated as 0.0004874:  log likelihood = 414.15,  aic = -818.31

# %%
Box.test(model$residuals,lag = 20,fitdf = 3)
# Out:
# 	Box-Pierce test
#
# data:  model$residuals
# X-squared = 18.599, df = 17, p-value = 0.352

# %%
ArchTest(model$residuals)
# Out:
# 	ARCH LM-test; Null hypothesis: no ARCH effects
#
# data:  model$residuals
# Chi-squared = 15.596, df = 12, p-value = 0.2104

# %%
model = arima(x = tsValuesLog_d_1,order = c(0,0,2))

# %%
model
# Out:
# Call:
# arima(x = tsValuesLog_d_1, order = c(0, 0, 2))
#
# Coefficients:
#          ma1     ma2  intercept
#       0.2363  0.1727     0.0003
# s.e.  0.0761  0.0697     0.0024
#
# sigma^2 estimated as 0.0004882:  log likelihood = 414.02,  aic = -822.05

# %%
Box.test(model$residuals,lag=20,fitdf = 2)
# Out:
# 	Box-Pierce test
#
# data:  model$residuals
# X-squared = 19.643, df = 18, p-value = 0.3533

# %%
ArchTest(model$residuals)
# Out:
# 	ARCH LM-test; Null hypothesis: no ARCH effects
#
# data:  model$residuals
# Chi-squared = 14.731, df = 12, p-value = 0.2565

# %%
model = arima(tsValuesLog_d_1,order = c(3,0,2))

# %%
model
# Out:
# Call:
# arima(x = tsValuesLog_d_1, order = c(3, 0, 2))
#
# Coefficients:
#          ar1     ar2      ar3      ma1      ma2  intercept
#       0.5163  0.2131  -0.1642  -0.2842  -0.1496     0.0003
# s.e.  0.5605  0.4452   0.1114   0.5679   0.3772     0.0022
#
# sigma^2 estimated as 0.000486:  log likelihood = 414.39,  aic = -816.78

# %%
Box.test(model$residuals,lag=20,fitdf = 5)
# Out:
# 	Box-Pierce test
#
# data:  model$residuals
# X-squared = 16.943, df = 15, p-value = 0.3223

# %%
ArchTest(model$residuals)
# Out:
# 	ARCH LM-test; Null hypothesis: no ARCH effects
#
# data:  model$residuals
# Chi-squared = 15.814, df = 12, p-value = 0.1999

# %%
res = model$residuals
